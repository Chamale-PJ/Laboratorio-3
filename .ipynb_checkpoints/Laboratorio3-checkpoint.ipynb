# %% [markdown]
# ![Logo](logoGalileo.png "Logo")
# ***
# # CIENCIA DE DATOS EN PYTHON SECCION *U*
# ## *LABORATORIO # 3*
# ##### **Pedro Josué Chamale Perez** - __23000478__

# %% [markdown]
# ##### *Parte 1: Numpy:*
#
# Para los ejercicios siguiente genere el código que considere
# para resolver el problema que se le plantea.
#
# 1.   ¿Cuál es el tamaño en bytes de un array de 1000 elementos de tipo booleano?

# %%
import numpy as np

#Elementos que formaran parte del array
elementos_booleanos = [True, False]

#Generando el array de longitud 10000
bool_array = np.random.choice(elementos_booleanos, size=1000)

print(bool_array.itemsize)
# Out:
# 1

# %% [markdown]
# 2. Cree un array cuyos elementos sean los enteros pares en [1,100] y en orden decreciente. Muestre los 10 últimos por pantalla.

# %%
n=100
lista=[]
    
while n>=0:
    lista.append(n)
    n-=2

print(lista)
print()
print(lista[-10:])
# Out:
# [100, 98, 96, 94, 92, 90, 88, 86, 84, 82, 80, 78, 76, 74, 72, 70, 68, 66, 64, 62, 60, 58, 56, 54, 52, 50, 48, 46, 44, 42, 40, 38, 36, 34, 32, 30, 28, 26, 24, 22, 20, 18, 16, 14, 12, 10, 8, 6, 4, 2, 0]
#
# [18, 16, 14, 12, 10, 8, 6, 4, 2, 0]

# %% [markdown]
# 3. Dado el array
#
#         2 4 5 6
#         0 3 7 4
#         8 8 5 2
#         1 5 6 1
#
#     Seleccione con una instrucción el subarray de elementos
#
#         0 3 7 4
#
#     Después, seleccione el subarray de elementos
#
#         2 5
#         8 5

# %%
list_matrix = [[2,4,5,6],
              [0,3,7,4],
              [8,8,5,2],
              [1,5,6,1]]

inciso_a = list_matrix[1][:]
print(inciso_a)
# Out:
# [0, 3, 7, 4]

# %%
print(list_matrix)

inciso_b = [[0,0],[0,0]]
i_index=0
j_index=0

for i in range(0,3,2):
    inciso_b[0][i_index] = list_matrix[0][i]
    i_index+=1
for j in range(0,3,2):
    inciso_b[1][j_index] = list_matrix[2][j]
    j_index+=1


print(inciso_b)
# Out:
# [[2, 4, 5, 6], [0, 3, 7, 4], [8, 8, 5, 2], [1, 5, 6, 1]]
# [[2, 5], [8, 5]]

# %% [markdown]
# 4.  Dados los arrays a = [1, 4, 2, 7] y b = [1, 3, 2, 9], obtenga la media aritmética de la diferencia (a-b).

# %%
a=[1,4,2,7]
b=[1,3,2,9]
a = np.array(a)
b = np.array(b)
c = np.array(a-b)
print("La media aritmetica: "+ str(np.mean(c)))
# Out:
# La media aritmetica: -0.25

# %% [markdown]
# 5. Tengo valores de cordenadas (x, y) en las columnas del array
#         1.33 4.5
#         30.0 10.7
#         70.2 0.5
#     Agregue a este array las coordenadas (37.1, -3.6). Muestre en pantalla las dimensiones del nuevo array.

# %%
Coordenadas =[[1.33,4.5],[30.0,10.7],[70.2,0.5]]
print(Coordenadas)

Coordenadas.append([37.1,-3.6])
print(Coordenadas)
print(np.shape(Coordenadas))
# Out:
# [[1.33, 4.5], [30.0, 10.7], [70.2, 0.5]]
# [[1.33, 4.5], [30.0, 10.7], [70.2, 0.5], [37.1, -3.6]]
# (4, 2)

# %% [markdown]
# 6. Copie el array del ejercicio anterior. Traspóngalo ( Agregue ahora dos nuevos pares de coordenadas: (10.8, 3.0) y (35.8, 12.0).

# %%
Transpuesto = np.array(Coordenadas)
nuevo_array = Transpuesto.T
print(nuevo_array)
agregar_f = np.append(nuevo_array[0], [10.8,35.8])
agregar_c = np.append(nuevo_array[1], [3.0,12.])
print(agregar_f, agregar_c)
Resultado = np.array([agregar_f,
                     agregar_c])
print()
print(Resultado)
# Out:
# [[ 1.33 30.   70.2  37.1 ]
#  [ 4.5  10.7   0.5  -3.6 ]]
# [ 1.33 30.   70.2  37.1  10.8  35.8 ] [ 4.5 10.7  0.5 -3.6  3.  12. ]
#
# [[ 1.33 30.   70.2  37.1  10.8  35.8 ]
#  [ 4.5  10.7   0.5  -3.6   3.   12.  ]]

# %% [markdown]
# ##### *Parte 2: Exploración y Minería de Datos:*
# Con el dataset nucleospoblacion.csv adjunto al laboratorio,
# luego responda las siguientes preguntas usando pandas y
# matplotlib.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 1. ¿Cuántos Municipios tienen más de 100000 habitantes?.

# %%
a_dataframe = pd.read_csv('NucleosPoblacion.csv')
a_dataframe = a_dataframe.sort_values('Poblacion',ascending=False)
a_dataframe.head()
# Out:
#      FID  OBJECTID      Texto  Poblacion  CodMun  Municipio  CodProvin  \
# 355  355       356     Madrid  3273049.0   28079     Madrid         28
# 623  623       624  Barcelona  1619337.0    8019  Barcelona          8
# 561  561       562   Valencia   809267.0   46250   Valencia         46
# 492  492       493    Sevilla   704198.0   41091    Sevilla         41
# 591  591       592   Zaragoza   675121.0   50297   Zaragoza         50
#
#              Provincia         X          Y
# 355             Madrid -3.703797  40.416630
# 623          Barcelona  2.176349  41.384247
# 561  València/Valencia -0.375657  39.475344
# 492            Sevilla -5.992514  37.386205
# 591           Zaragoza -0.879287  41.656457

# %%
a_dataframe[a_dataframe["Poblacion"]>100000]
# Out:
#      FID  OBJECTID       Texto  Poblacion  CodMun   Municipio  CodProvin  \
# 355  355       356      Madrid  3273049.0   28079      Madrid         28
# 623  623       624   Barcelona  1619337.0    8019   Barcelona          8
# 561  561       562    Valencia   809267.0   46250    Valencia         46
# 492  492       493     Sevilla   704198.0   41091     Sevilla         41
# 591  591       592    Zaragoza   675121.0   50297    Zaragoza         50
# ..   ...       ...         ...        ...     ...         ...        ...
# 336  336       337  Alcobendas   110080.0   28006  Alcobendas         28
# 108  108       109     Ourense   108673.0   32054     Ourense         32
# 735  735       736        Reus   106622.0   43123        Reus         43
# 194  194       195  Torrevieja   101091.0    3133  Torrevieja          3
# 16    16        17       Telde   100900.0   35026       Telde         35
#
#              Provincia          X          Y
# 355             Madrid  -3.703797  40.416630
# ...

# %%
#Cantidad de Municipios que cumplen con la condicion
len(a_dataframe[a_dataframe["Poblacion"]>100000])
# Out:
# 62

# %% [markdown]
# 2. Realice una gráfica de barras sobre la polbación de cada ciudad, ordenela de menor a mayo y responda:
#         a. ¿Cuál es la segunda ciudad más poblada?
#         b. ¿Qué posición ocupa Granada en el ranking de las ciudades más pobladas?

# %%
x_graph = a_dataframe['Provincia'].values
y_graph = a_dataframe['Poblacion'].values

plt.figure(figsize=(10,10))
plt.barh(x_graph, y_graph)
plt.show()

# %%
a_ = a_dataframe['Provincia']=='Barcelona'
print("La poblacion de la segunda ciudad (Barcelona) mas poblada es igual: ")
a_dataframe[a_].sum()['Poblacion']
# Out:
# La poblacion de la segunda ciudad (Barcelona) mas poblada es igual:
# 4934795.0

# %% [markdown]
# Granada ocupa la posicion 17 en el ranking de ciudades mas pobladas

# %% [markdown]
# 3. ¿Cuántos municipios de Extremadura tienen más de 5000 habitantes?.

# %%
a_dataframe[a_dataframe['Municipio']=='Extremadura']
# Out:
# Empty DataFrame
# Columns: [FID, OBJECTID, Texto, Poblacion, CodMun, Municipio, CodProvin, Provincia, X, Y]
# Index: []

# %% [markdown]
# 4. ¿Cuál es el municipio situado más al Norte? (Usar el valor de la coordenada "Y" que representa la latitud en grados). Proporcione también la provincia a la que pertenece y su población.

# %%
a_dataframe[a_dataframe['Y']==a_dataframe['Y'].max()]
# Out:
#      FID  OBJECTID    Texto  Poblacion  CodMun Municipio  CodProvin Provincia  \
# 104  104       105  Viveiro    16211.0   27066   Viveiro         27      Lugo
#
#             X          Y
# 104 -7.588768  43.625578

# %% [markdown]
# 5. Obtenga la media, mediana, desviación estándar, valor máximo y valor mínimo de la población de los municipios de la provincia de Granada.

# %%
a_dataframe[a_dataframe['Provincia']=='Granada'].describe()
# Out:
#              FID   OBJECTID      Poblacion        CodMun  CodProvin  \
# count   20.00000   20.00000      20.000000     20.000000       20.0
# mean   275.50000  276.50000   30217.850000  18140.900000       18.0
# std      5.91608    5.91608   50355.491715    189.385961        0.0
# min    266.00000  267.00000   10386.000000  18003.000000       18.0
# 25%    270.75000  271.75000   13146.500000  18052.250000       18.0
# 50%    275.50000  276.50000   17526.000000  18112.000000       18.0
# 75%    280.25000  281.25000   21739.750000  18154.250000       18.0
# max    285.00000  286.00000  239154.000000  18905.000000       18.0
#
#                X          Y
# count  20.000000  20.000000
# mean   -3.606477  37.139321
# std     0.266746   0.191057
# min    -4.152187  36.734414
# 25%    -3.689279  37.131378
# 50%    -3.631257  37.171351
# 75%    -3.587665  37.230955
# max    -2.774856  37.490778

# %% [markdown]
# 6. Realice un histograma con la población de los Municipios para cada una de las provincias.

# %%
plt.figure(figsize=(10,10))
plt.hist(x_graph,alpha=0.5,orientation='horizontal')
plt.show()

# %% [markdown]
# 7. Seleccione al azar cincuenta municipios diferentes de entre los diponibles en el archivo. Asegúrese de que no se repitan. ¿Luego calcule el promedio de la población y la desviación estándar de esto 50 municipios?.

# %%
#Se seleccionan 50 datos al azar del DataFrame Total
df_muestra = a_dataframe.sample(n=50)
df_muestra
# Out:
#      FID  OBJECTID                          Texto  Poblacion  CodMun  \
# 231  231       232              Borriana/Burriana    34896.0   12032
# 370  370       371     San Lorenzo de El Escorial    18352.0   28131
# 457  457       458                   Villaviciosa    14840.0   33076
# 751  751       752             Trobajo del Camino    21231.0   24142
# 196  196       197           Pilar de la Horadada    22555.0    3902
# 579  579       580                    Portugalete    47856.0   48078
# 723  723       724                         Monzón    17115.0   22158
# 769  769       770                  El Sobradillo    14094.0   38038
# 463  463       464                       Muriedas    31552.0   39016
# 542  542       543                        Meliana    10536.0   46166
# 305  305       306                        Bergara    14637.0   20074
# 543  543       544                        Mislata    43792.0   46169
# 89    89        90                         Huelva   149310.0   21041
# ...

# %%
df_muestra.describe()
# Out:
#               FID    OBJECTID      Poblacion        CodMun  CodProvin  \
# count   50.000000   50.000000      50.000000     50.000000   50.00000
# mean   460.700000  461.700000   44794.520000  23611.000000   23.50000
# std    237.121621  237.121621   66221.918956  14551.750785   14.57598
# min      7.000000    8.000000   10097.000000   3031.000000    3.00000
# 25%    262.000000  263.000000   14761.500000   8480.250000    8.25000
# 50%    467.500000  468.500000   23211.000000  23086.000000   23.00000
# 75%    664.250000  665.250000   46840.000000  35794.000000   35.75000
# max    835.000000  836.000000  441345.000000  48078.000000   48.00000
#
#                X          Y
# count  50.000000  50.000000
# mean   -2.665299  40.099510
# std     4.102016   3.154512
# min   -16.325895  28.440119
# 25%    -4.594919  38.576888
# 50%    -2.715281  40.369989
# 75%    -0.095403  42.446157
# max     3.837940  43.479942

# %% [markdown]
# 8. Dígame los nombres de los Municipios más cercano y más lejano a Madrid. Para ello debe calcular la distancia en todos ellos y Madrid. No considere a Madrid en el análisis ya que la distancia sería cero

# %%
#Obteniendo las coordenadas del Municipio de Madrid
x_madrid=a_dataframe[a_dataframe['Municipio'] == 'Madrid']['X']
y_madrid=a_dataframe[a_dataframe['Municipio'] == 'Madrid']['Y']

print(x_madrid.values, y_madrid.values)
# Out:
# [-3.70379708] [40.41663]

# %%
a_dataframe['Distancia'] = pow(pow(a_dataframe['X'].values - x_madrid.values,2) + 
            pow(a_dataframe['Y'].values - y_madrid.values,2),0.5) 

#Mostrando los valores de los Municipios mas cercanos a Madrid
a_dataframe.sort_values('Distancia').head(n=20)
# Out:
#      FID  OBJECTID                            Texto  Poblacion  CodMun  \
# 355  355       356                           Madrid  3273049.0   28079
# 783  783       784  Humera-Somosaguas-prado del Rey    14800.0   28115
# 780  780       781                       El Bercial    12814.0   28065
# 781  781       782                          Fortuna    12840.0   28074
# 354  354       355                          Leganés   187227.0   28074
# 365  365       366               Pozuelo de Alarcón    82804.0   28115
# 351  351       352                           Getafe   169130.0   28065
# 347  347       348                          Coslada    91218.0   28049
# 337  337       338                         Alcorcón   168299.0   28007
# 336  336       337                       Alcobendas   110080.0   28006
# 372  372       373       San Sebastián de los Reyes    78157.0   28134
# 349  349       350                      Fuenlabrada   198973.0   28058
# ...

# %%
#Listando los nombres de los municipios mas cercanos a Madrid
a_dataframe.sort_values('Distancia').head(n=20)['Municipio'].values
# Out:
# array(['Madrid', 'Pozuelo de Alarcón', 'Getafe', 'Leganés', 'Leganés',
#        'Pozuelo de Alarcón', 'Getafe', 'Coslada', 'Alcorcón',
#        'Alcobendas', 'San Sebastián de los Reyes', 'Fuenlabrada',
#        'Rivas-Vaciamadrid', 'San Fernando de Henares',
#        'Boadilla del Monte', 'Pinto', 'Fuenlabrada', 'Majadahonda',
#        'Móstoles', 'Las Rozas de Madrid'], dtype=object)

# %%
#Mostrando los valores de los Municipios mas lejanos a Madrid
a_dataframe.sort_values('Distancia').tail(n=20)
# Out:
#      FID  OBJECTID                   Texto  Poblacion  CodMun  \
# 33    33        34            La Esperanza    17417.0   38032
# 38    38        39               Tacoronte    23615.0   38043
# 23    23        24              Candelaria    25140.0   38011
# 36    36        37            Santa Úrsula    14143.0   38039
# 26    26        27                  Güímar    17852.0   38020
# 30    30        31              La Orotava    41427.0   38026
# 31    31        32       Puerto de la Cruz    32571.0   38028
# 32    32        33            Realejo Alto    37658.0   38031
# 27    27        28       Icod de los Vinos    24231.0   38022
# 24    24        25     Granadilla de Abona    40862.0   38017
# 766  766       767              San Isidro    18371.0   38017
# 34    34        35              San Miguel    16707.0   38035
# 37    37        38      Santiago del Teide    12099.0   38040
# 25    25        26           Guía de Isora    20535.0   38019
# ...

# %%
#Listando los nombres de los municipios mas lejanos a Madrid
a_dataframe.sort_values('Distancia').tail(n=20)['Municipio'].values
# Out:
# array(['El Rosario', 'Tacoronte', 'Candelaria', 'Santa Úrsula', 'Güímar',
#        'La Orotava', 'Puerto de la Cruz', 'Los Realejos',
#        'Icod de los Vinos', 'Granadilla de Abona', 'Granadilla de Abona',
#        'San Miguel de Abona', 'Santiago del Teide', 'Guía de Isora',
#        'Arona', 'Adeje', 'Adeje', 'Arona', 'Santa Cruz de la Palma',
#        'Los Llanos de Aridane'], dtype=object)
